# %% [markdown]
# <a href="https://colab.research.google.com/github/s0ku00/DTS/blob/main/Deep_Learning_and_Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
# !pip install streamlit
# !pip install SpeechRecognition
# !pip install pyngrok --quiet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 62.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 79.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 12.3 MB/s eta 0:00:00
# ...

# %%
# %%writefile speech_enabled_chatbot.py
from nltk.tokenize import word_tokenize
import streamlit as st
import nltk
import speech_recognition as sr
import string
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Load the text file and preprocess the data
def load_and_preprocess_chatbot_data(filepath):
    """Loads the chatbot text data and tokenizes it into sentences."""
    with open('/content/Practical Physiology.txt', 'r', encoding='utf-8') as f:
        data = f.read().replace('\n', ' ')

    sentences = sent_tokenize(data)
    return sentences

# Preprocessing function for each sentence
def preprocess(sentence):
    """Tokenize, remove stopwords and punctuation, and lemmatize words in a sentence."""
    words = word_tokenize(sentence)
    stop_words = set(stopwords.words('english'))

    words = [word.lower() for word in words if word.lower() not in stop_words and word not in string.punctuation]

    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]

    return words

# Function to find the most relevant sentence given a query
def get_most_relevant_sentence(query, corpus):
    """Find the most relevant sentence in the corpus using Jaccard similarity."""
    query = preprocess(query)  # Preprocess query

    max_similarity = 0
    most_relevant_sentence = ""

    # Compute similarity between the query and each sentence in the corpus
    for sentence in corpus:
        processed_sentence = preprocess(sentence)

        # Jaccard similarity: intersection / union
        similarity = len(set(query).intersection(processed_sentence)) / float(len(set(query).union(processed_sentence)))

        if similarity > max_similarity:
            max_similarity = similarity
            most_relevant_sentence = sentence  # Store the original sentence

    return most_relevant_sentence

# Speech recognition function
def transcribe_speech(api_choice):
    """Use SpeechRecognition to transcribe voice input to text using selected API."""
    r = sr.Recognizer()
    with sr.Microphone() as source:
        st.info("Listening...")
        audio_text = r.listen(source)

        try:
            st.info("Transcribing...")
            if api_choice == "Google":
                text = r.recognize_google(audio_text)
            elif api_choice == "Sphinx":
                text = r.recognize_sphinx(audio_text)
            return text
        except sr.UnknownValueError:
            return "Sorry, I could not understand the audio."
        except sr.RequestError as e:
            return f"Could not request results from API; {e}"

# Main function for Streamlit app
def main():
    st.title("Speech-Enabled Physiology Chatbot")

    # Load and preprocess the chatbot data
    chatbot_data = load_and_preprocess_chatbot_data('/content/Practical Physiology.txt')

    st.write("You can either type your message or use the microphone to speak.")

    # User chooses between text input or speech
    input_mode = st.radio("Choose Input Mode", ("Text", "Speech"))

    # If user chooses speech, allow them to select the API
    api_choice = None
    if input_mode == "Speech":
        api_choice = st.selectbox("Choose Speech Recognition API", ["Google", "Sphinx"])

    if input_mode == "Text":
        user_input = st.text_input("Type your message here:")
        if user_input:
            response = get_most_relevant_sentence(user_input, chatbot_data)
            st.write("Chatbot: ", response)

    elif input_mode == "Speech":
        if st.button("Start Recording"):
            user_input = transcribe_speech(api_choice)
            st.write("You said: ", user_input)

            if user_input:
                response = get_most_relevant_sentence(user_input, chatbot_data)
                st.write("Chatbot: ", response)

if __name__ == "__main__":
    main()
# Out:
# Overwriting speech_enabled_chatbot.py

# %%
# !npm install localtunnel
# Out:
# up to date, audited 23 packages in 728ms
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 2 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.

# %%
# !streamlit run speech_enabled_chatbot.py & npx localtunnel --port 8501 & curl -s ipv4.icanhazip.com
# Out:
# 34.46.209.235
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.46.209.235:8501
#
# your url is: https://some-dots-feel.loca.lt
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ...
