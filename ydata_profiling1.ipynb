# %% [markdown]
# <a href="https://colab.research.google.com/github/s0ku00/DTS/blob/main/ydata_profiling1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Data exploration with Pandas

import pandas as pd

ydata = pd.read_csv('/content/sample_data/EDUCATION_ATTAINMENT.csv')
print(ydata.head(10))
print(ydata.info())
# Out:
#    Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# 0                0.669091                0.667214                0.651812
# 1                0.485879                0.480171                0.465510
# 2                0.516431                0.514233                0.502269
# 3                0.914294                0.903528                0.871690
# 4                0.876990                0.841497                0.762864
# 5                0.889589                0.852069                0.771968
# 6                0.803733                0.746789                0.631720
# 7                0.981062                0.981062                0.980476
# 8                0.991079                0.985556                0.981743
# 9                0.992481                0.990077                0.984427
#
#    Ages[20-29]_All_grade1  Ages[20-29]_All_grade2  Ages[20-29]_All_grade3  \
# 0                0.460899                0.458749                0.446925
# ...

# %%
print (ydata.describe())
# Out:
#        Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.873886                0.861490                0.837509
# std                  0.162624                0.166895                0.176555
# min                  0.251917                0.244071                0.233274
# 25%                  0.831791                0.803131                0.757465
# 50%                  0.948926                0.935167                0.909587
# 75%                  0.984447                0.980112                0.971166
# max                  1.000000                1.000000                1.000000
#
#        Ages[20-29]_All_grade1  Ages[20-29]_All_grade2  Ages[20-29]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.823849                0.812738                0.789965
# ...

# %%
# Step 2: Data exploration with ydata-profiling

# !pip install pandas-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 30.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 9.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 42.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 22.1 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=64ac66cd1fcf13a05a883a02adee59b8c0b2a5f9ec0a2d53ad9dd4d934a7c5cb
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
from ydata_profiling import ProfileReport

yprofile = ProfileReport(ydata, title='Pandas Profiling Report')

# Generate an HTML report
yprofile.to_file("ydata_1.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
'''
The dataset has a total of 18 missing cells
The report shows high level of correlations between the numeric columns
Based on the graphs from the variable and interaction sections the plot shows a
high performance index with the overall average not going below 50.

'''
